# %% [markdown]
# <a href="https://colab.research.google.com/github/foolu01/Gen-AI/blob/main/Python_for_generative_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=6
x
# Out:
# 6

# %%
y=0
y
# Out:
# 0

# %%
x=7
y=9
z=x+y
z
# Out:
# 16

# %%
my_sub= "generative ai"
my_sub
# Out:
# 'generative ai'

# %%
my_city="SOLAN"
my_city
# Out:
# 'SOLAN'

# %%
1mycity ="shimla"
1mycity
# Out:
#   File "/tmp/ipython-input-2129748771.py", line 1
#     1mycity ="shimla"
#     ^
# SyntaxError: invalid decimal literal

# %%
import keyboard
keyword.kwlist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3883516917.py in <cell line: 0>()
# ----> 1 import keyboard
#       2 keyword.kwlist
#
# ModuleNotFoundError: No module named 'keyboard'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
x=1
type(x)
# Out:
# int

# %%
y=0.0
type(y)
# Out:
# float

# %%
z=3+4j
type(z)
# Out:
# complex

# %%
#string---data in the form of text
a="Solan"
type(a)
# Out:
# str

# %%
#boolean--it is used to store a value that is True and False
x=True
type(x)
# Out:
# bool

# %%
y= False
type(y)
# Out:
# bool

# %%
#None-- it is null value means nothing
e =None
type(e)
# Out:
# NoneType

# %%
#addition
2+2
# Out:
# 4

# %%
x=4
y=6
z=x+y
z
# Out:
# 10

# %%
#subtraction
a= 10
b= 1000000000000000000000000000000000000000000000
c=a-b
c
# Out:
# -999999999999999999999999999999999999999999990

# %%
#multiplication
a=5
b=2
c=a*b
print(c)
# Out:
# 10

# %%
#division
a=10
b=5
c=a/b
c
# Out:
# 2.0

# %%
#expontiation
a=2
b=3
c=a**b
print(c)
# Out:
# 8

# %%
#floor division -- return the result in whole number
7//2
# Out:
# 3

# %%
7.0//2
# Out:
# 3.0

# %%
#modulus -- the output is remainder
5%2
# Out:
# 1

# %%
#modulus -- through variable
a=5
b=2
c=a%b
c
# Out:
# 1

# %%
1+1
# Out:
# 2

# %%
#String--
my_sub="machine learning"
type(my_sub)
# Out:
# str

# %%
#single quote string
my_college='Shoolini University'
type(my_college)
# Out:
# str

# %%
#TRIPLE QUOTE STRING
my_sentence='''This sentence is multiple line,
this is also a string type'''
type(my_sentence)
# Out:
# str

# %%
#find the length of string
my_sub="machine learning"
len(my_sub)
# Out:
# 16

# %%
  my_sub[0]
# Out:
# 'm'

# %%
my_sub[1]
# Out:
# 'a'

# %%
my_sub[-1]
# Out:
# 'g'

# %%
my_sub[-9]
# Out:
# ' '

# %%
my_sub[0:7:1] #by default sequence is 1
# Out:
# 'machine'

# %%
my_list= [90,87,65,34]
print(my_list)
my_list.append(100)
print(my_list)
# Out:
# [90, 87, 65, 34]
# [90, 87, 65, 34, 100]

# %%
my_list[2]=200
print(my_list)
# Out:
# [90, 87, 200, 34, 100]

# %%
list1= [90,78,65]
list2=[56,89,45]
list1.extend(list2)
print(list1)
# Out:
# [90, 78, 65, 56, 89, 45]

# %%
my_list=[78,56,34,12]
my_list.pop()
# Out:
# 12

# %%
list1=[90,87,65,23]
list1.remove(87)
list1
# Out:
# [90, 65, 23]

# %%
my_list =[90,8,56,23]
my_list.reverse()
print(my_list)
# Out:
# [23, 56, 8, 90]

# %%
my_dict ={"name":"Amit", "college":"Shoolini University"}
type(my_dict)
# Out:
# dict

# %%
print(my_dict)
# Out:
# {'name': 'Amit', 'college': 'Shoolini University'}

# %%
print(my_dict["name"])
print(my_dict["college"])
# Out:
# Amit
# Shoolini University

# %%
list(my_dict.keys())
# Out:
# ['name', 'college']

# %%
my_dict.values()
# Out:
# dict_values(['Amit', 'Shoolini University'])

# %%
list(my_dict.items())
# Out:
# [('name', 'Amit'), ('college', 'Shoolini University')]

# %%
my_dict.get("name")
# Out:
# 'Amit'

# %%
my_dict.update({"Age":20})
print(my_dict)
# Out:
# {'name': 'Amit', 'college': 'Shoolini University', 'Age': 20}

# %%
#loops and control statement
#Break -- this statement break the loop
i=0
while i<5:
  i+=1#increment
  if i==3:
    break
  else:
   print(i)
# Out:
# 1
# 2

# %%
#continue statement -- this statement skip the current iteration
i = 0
while i<5:
  i+=1
  if i==3:
    continue
  else:
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#pass statement -- this statement pass the code
i=0
while i<5:
  i+=1
  if i==3:
    pass
    print(i)
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
 #positional argument
 def calculation(A,b):
    print("addition",A+b)
    print("subtraction",A-b)
    print("multiplication",A*b)
    print("division",A/b)

# %%
print(calculation(10,5))
# Out:
# addition 15
# subtraction 5
# multiplication 50
# division 2.0
# None

# %%
-

# %%
xpoint= np.array([1,3])
ypoint= np.array([2,4])
plt.plot(xpoint,ypoint)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4121391218.py in <cell line: 0>()
# ----> 1 xpoint= np.array([1,3])
#       2 ypoint= np.array([2,4])
#       3 plt.plot(xpoint,ypoint)
#       4 plt.show()
#
# NameError: name 'np' is not defined

# %%
p

# %%
english_movie.to_Csv("english_movie.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2006865175.py in <cell line: 0>()
# ----> 1 english_movie.to_Csv("english_movie.csv")
#
# NameError: name 'english_movie' is not defined

# %%
import numpy as np
from numpy.linalg import norm
A=np.array([2,1,2,3,2,9])
B=np.array([3,4,2,4,5,5])

cosine= np.dot(A,B)/(norm(A)*norm(B))
print(cosine)
# Out:
# 0.8188504723485274

# %%
from  transformers import pipeline
summarizer = pipeline("summarization",model="facebook/bart-large-cnn")
text="""the global shift toward renewable energy is accelerating driven by concerns over climate change and energy security.solar and wind power installations have reached record levels worldwide."""
summary=summarizer (text , max_length=30,min_length=10,do_sample=False)
print(summary[0])
# Out:
# Device set to use cpu
# {'summary_text': 'The global shift toward renewable energy is accelerating driven by concerns over climate change and energy security.'}
